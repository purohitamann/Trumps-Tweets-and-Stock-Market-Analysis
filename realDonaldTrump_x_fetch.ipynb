# %%
# !pip install tweepy pandas

# %%
import tweepy
import pandas as pd
from google.colab import userdata
# Set up Twitter API credentials
api_key = userdata.get('X_API_KEY')
api_secret = userdata.get('X_API_SECRET')
access_token = userdata.get('X_ACCESS_TOKEN')
access_token_secret = userdata.get('X_ACCESS_TOKEN_SECRET')

# Authenticate with Twitter API
auth = tweepy.OAuth1UserHandler(api_key, api_secret, access_token, access_token_secret)
api = tweepy.API(auth)

# Specify Twitter handle for Trump (historical: realDonaldTrump)
user_handle = "realDonaldTrump"

# Fetch tweets
tweets = []
for status in tweepy.Cursor(api.user_timeline, screen_name=user_handle, tweet_mode="extended").items(1000):
    tweets.append({
        "created_at": status.created_at,
        "text": status.full_text,
        "likes": status.favorite_count,
        "retweets": status.retweet_count
    })

# Convert to DataFrame
df = pd.DataFrame(tweets)

# Save to CSV
df.to_csv("trump_tweets.csv", index=False)
print("Trump's tweets saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-3-b5a91020bf27> in <cell line: 19>()
#      17 # Fetch tweets
#      18 tweets = []
# ---> 19 for status in tweepy.Cursor(api.user_timeline, screen_name=user_handle, tweet_mode="extended").items(1000):
#      20     tweets.append({
#      21         "created_at": status.created_at,
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
import tweepy
import pandas as pd
from google.colab import userdata
# Twitter API v2 credentials
bearer_token = userdata.get('BEARER_TOKEN')

# Initialize Tweepy client
client = tweepy.Client(bearer_token=bearer_token)

# Fetch tweets using Twitter API v2
query = "from:realDonaldTrump"  # Trump's Twitter username
tweets = []

# Fetch up to 100 tweets
response = client.search_recent_tweets(query=query, max_results=100, tweet_fields=['created_at', 'public_metrics'])

# Process tweets
for tweet in response.data:
    tweets.append({
        "created_at": tweet.created_at,
        "text": tweet.text,
        "likes": tweet.public_metrics["like_count"],
        "retweets": tweet.public_metrics["retweet_count"]
    })

# Convert to DataFrame
df = pd.DataFrame(tweets)
df.to_csv("trump_tweets_v1.csv", index=False)
print("Tweets saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-8-c24efd4170c8> in <cell line: 15>()
#      13
#      14 # Fetch up to 100 tweets
# ---> 15 response = client.search_recent_tweets(query=query, max_results=200, tweet_fields=['created_at', 'public_metrics'])
#      16
#      17 # Process tweets
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1264         """
#    1265         params["query"] = query
# -> 1266         return self._make_request(
#    1267             "GET", "/2/tweets/search/recent", params=params,
#    1268             endpoint_parameters=(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
# ...

# %%
df = pd.read_csv("trump_tweets_v2.csv")
df.head()
# Out:
#                   created_at  \
# 0  2024-12-16 23:18:25+00:00
# 1  2024-12-16 22:58:16+00:00
# 2  2024-12-16 03:41:42+00:00
# 3  2024-12-15 21:30:46+00:00
# 4  2024-12-15 21:19:44+00:00
#
#                                                 text  likes  retweets
# 0  @OtavioCo2 \n\nAuto-reply from Team Trump:\n\n...      0         0
# 1  @af_game_r \n\nAuto-reply from Team Trump:\n\n...      0         0
# 2  @delires68 \n\nAuto-reply from Team Trump:\n\n...      0         0
# 3  @TalhaKeser30978 \n\nAuto-reply from Team Trum...      0         0
# 4  @mochisnall \n\nAuto-reply from Team Trump:\n\...      0         1

# %%
df
# Out:
#                    created_at  \
# 0   2024-12-16 23:18:25+00:00
# 1   2024-12-16 22:58:16+00:00
# 2   2024-12-16 03:41:42+00:00
# 3   2024-12-15 21:30:46+00:00
# 4   2024-12-15 21:19:44+00:00
# 5   2024-12-15 20:07:59+00:00
# 6   2024-12-15 18:28:26+00:00
# 7   2024-12-15 11:06:53+00:00
# 8   2024-12-15 09:43:53+00:00
# 9   2024-12-15 00:57:12+00:00
# 10  2024-12-15 00:08:54+00:00
# 11  2024-12-14 18:30:55+00:00
# 12  2024-12-14 09:49:42+00:00
# 13  2024-12-14 06:31:52+00:00
# 14  2024-12-14 03:17:57+00:00
# 15  2024-12-13 21:40:17+00:00
# 16  2024-12-13 17:19:42+00:00
# 17  2024-12-13 12:42:19+00:00
# 18  2024-12-13 09:25:34+00:00
# 19  2024-12-12 04:14:27+00:00
# 20  2024-12-12 02:40:21+00:00
# 21  2024-12-12 00:25:26+00:00
# 22  2024-12-11 19:18:03+00:00
# 23  2024-12-10 18:19:37+00:00
# 24  2024-12-10 05:50:34+00:00
#
#                                                  text   likes  retweets
# 0   @OtavioCo2 \n\nAuto-reply from Team Trump:\n\n...       0         0
# ...

# %%
df.describe()
# Out:
#                likes     retweets
# count      25.000000     25.00000
# mean    80000.400000   8673.80000
# std    194533.577007  20554.18112
# min         0.000000      0.00000
# 25%         0.000000      0.00000
# 50%         0.000000      0.00000
# 75%         1.000000      1.00000
# max    813183.000000  78359.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  25 non-null     object
#  1   text        25 non-null     object
#  2   likes       25 non-null     int64
#  3   retweets    25 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 928.0+ bytes

# %%
df.at[0, 'text']
# Out:
# '@OtavioCo2 \n\nAuto-reply from Team Trump:\n\nWe’ll send you IMPORTANT ELECTION UPDATES. Make sure you’re ready to VOTE FOR DONALD J. TRUMP by November 5th.\n\nText TRUMP to 88022\n\nShare this post: https://t.co/IiaWVAl0My\n\nReply #stop to opt-out.'
